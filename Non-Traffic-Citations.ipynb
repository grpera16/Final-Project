# %% [markdown]
# **Introduction:** Our project is to find the most dangerous neighborhood based on the severity of the citations that are not arrested. I came up with this metric because I am moving off campus next year and am curious about how safe the neighborhood I am moving into it
#
# **Metric:** I am using the Non Traffic Citations database

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
def filter_neighborhood(x, threshold): 
    return (x["NEIGHBORHOOD"].count() >= threshold)

crime_rate = citations.groupby("OFFENSES").filter(filter_neighborhood, threshold=1000)


neighborhood_counts = crime_rate.groupby("OFFENSES").size()

plt.figure(figsize=(10, 6))
neighborhood_counts.plot(kind='bar')
plt.xlabel('Offense')
plt.ylabel('Times Offense has Occured')
plt.title('Number of Offenses Occured (Threshold >= 1000)')
plt.xticks(rotation=90)
plt.show()

# %%
def filter_offenses(x, threshold): 
    return (x["OFFENSES"].count() >= threshold)

crime_rate = citations.groupby("NEIGHBORHOOD").filter(filter_offenses, threshold=400)


neighborhood_counts = crime_rate.groupby("NEIGHBORHOOD").size()

plt.figure(figsize=(10, 6))
neighborhood_counts.plot(kind='bar')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Offenses')
plt.title('Number of Offenses in Each Neighborhood (Threshold >= 400)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
