# %% [markdown]
# **Introduction:** Our project is to find the most dangerous neighborhood based on the severity of the citations that are not arrested. I came up with this metric because I am moving off campus next year and am curious about how safe the neighborhood I am moving into it
#
# **Metric:** I am using the Non Traffic Citations database

# %%
import pandas as pd 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
citations = pd.read_csv("Citations.csv", index_col = "_id")
citations.head(10)
# Out:
#           PK       CCR GENDER RACE   AGE            CITEDTIME  \
# _id
# 1    1078081  16157849      M    B  29.0  2016-08-22T23:45:00
# 2    1078082  16157849      M    W  21.0  2016-08-22T23:45:00
# 3    1078083  16159579    NaN  NaN   NaN  2016-08-25T11:10:00
# 4    1078084  16159780      M    B  22.0  2016-08-25T16:42:00
# 5    1078085  16161591      F    W  22.0  2016-08-28T00:58:00
# 6    1078086  16162400      M    W  28.0  2016-08-29T10:34:00
# 7    1078087  16162524      M    B  56.0  2016-08-29T13:00:00
# 8    1078088  16162524      M    W  44.0  2016-08-29T13:00:00
# 9    1078089  16083638      M    W  50.0  2016-05-07T16:30:00
# 10   1078090  16077700      M    B  24.0  2016-04-29T01:05:00
#
#                              INCIDENTLOCATION  \
# _id
# 1    200 Block N DITHRIDGE ST PITTSBURGH, PA
# 2    200 Block N DITHRIDGE ST PITTSBURGH, PA
# 3                  NORTH PARK PITTSBURGH, PA
# 4    7200 Block FRANKSTOWN AV PITTSBURGH, PA
# 5        6100 Block BERLIN WY PITTSBURGH, PA
# 6          MARKET ST & 5TH AV PITTSBURGH, PA
# 7       MARKET ST & FORBES AV PITTSBURGH, PA
# 8       MARKET ST & FORBES AV PITTSBURGH, PA
# 9        40TH ST & DAVISON ST PITTSBURGH, PA
# 10         80 Block S 15TH ST PITTSBURGH, PA
#
#                                               OFFENSES  \
# _id
# 1    5503(a)(2) DISORDERLY CONDUCT - UNREASONABLE N...
# 2    5503(a)(2) DISORDERLY CONDUCT - UNREASONABLE N...
# 3                              5505 Public Drunkenness
# 4    6501(a)(1) Scattering Rubbish; Any waste, dang...
# 5    5503(a)(2) DISORDERLY CONDUCT - UNREASONABLE N...
# 6    5507(a) Obstructing highway, railroad or publi...
# 7                        601.08 (a) Open Container Law
# 8                        601.08 (a) Open Container Law
# 9                              5505 Public Drunkenness
# 10   3304(a)(5) CRIMINAL MISCHIEF - Intentionally D...
#
#                     NEIGHBORHOOD ZONE INCIDENTTRACT  COUNCIL_DISTRICT  \
# _id
# 1                  North Oakland    4           507               8.0
# 2                  North Oakland    4           507               8.0
# 3               Allegheny Center    1          2204               NaN
# 4                 Homewood South    5          1303               9.0
# 5            Upper Lawrenceville    2          1011               7.0
# 6    Golden Triangle/Civic Arena    2           201               6.0
# 7    Golden Triangle/Civic Arena    1           201               6.0
# 8    Golden Triangle/Civic Arena    1           201               6.0
# 9            Lower Lawrenceville    2           603               7.0
# 10              South Side Flats    3          1702               3.0
#
#      PUBLIC_WORKS_DIVISION          X          Y
# _id
# 1                      3.0 -79.951692  40.449311
# 2                      3.0 -79.951692  40.449311
# 3                      NaN        NaN        NaN
# 4                      2.0 -79.896254  40.457329
# 5                      2.0 -79.946664  40.485403
# 6                      6.0 -80.002109  40.441383
# 7                      6.0 -80.002190  40.440584
# 8                      6.0 -80.002190  40.440584
# 9                      2.0 -79.960903  40.467585
# 10                     3.0 -79.983573  40.428555
